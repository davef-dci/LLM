# %% [markdown]
# <a href="https://colab.research.google.com/github/davef-dci/LLM/blob/dcf_Colab_Virtual_GPU/Copy_of_LLM_Rag.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# !mkdir local-rag
# !cd local-rag
# Out:
# mkdir: cannot create directory ‘local-rag’: File exists

# %%
# !pip install chromadb

# %%
# !pip install --q unstructured langchain langchain-text-splitters

# %%
# !pip install --q "unstructured[all-docs]"

# %%
# !pip install --q flask

# %%
# !sudo apt-get install -y pciutils
# !curl -fsSL https://ollama.ai/install.sh | sh
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# pciutils is already the newest version (1:3.7.0-6).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ############################################################################################# 100.0%
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# >>> NVIDIA GPU installed.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
import os
os.environ['NGROK_AUTH_TOKEN'] = '2mLFit1NLrroBlEQylbg4wae8Wd_4F9XUsDDVsCWG8oWpgbvL'

# %%
# !pip install pyngrok --quiet
import os
import asyncio
from pyngrok import ngrok

# Ensure the GPU is available and libraries are correctly set
os.environ['LD_LIBRARY_PATH'] = '/usr/lib64-nvidia'

async def run(cmd):
    print(f'Running command: {" ".join(cmd)}')
    process = await asyncio.create_subprocess_exec(
        *cmd, stdout=asyncio.subprocess.PIPE, stderr=asyncio.subprocess.PIPE
    )

# Start Ngrok and Ollama simultaneously
async def start_services():
    await asyncio.gather(
        run(['ollama', 'serve']),
        run(['ngrok', 'http', '11434'])  # 11434 is the Ollama server port
    )

await start_services()
# Out:
# Running command: ollama serve
# Running command: ngrok http 11434

# %%
# !lsof -i :11434
# Out:
# COMMAND   PID USER   FD   TYPE DEVICE SIZE/OFF NODE NAME
# ollama  16970 root    3u  IPv4 415155      0t0  TCP localhost:11434 (LISTEN)

# %%
# !ollama pull mistral
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest
# pulling ff82381e2bea... 100% ▕▏ 4.1 GB
# pulling 43070e2d4e53... 100% ▕▏  11 KB
# pulling 491dfa501e59... 100% ▕▏  801 B
# pulling ed11eda7790d... 100% ▕▏   30 B
# pulling 42347cd80dc8... 100% ▕▏  485 B
# verifying sha256 digest
# writing manifest
# success

# %%
# !ollama pull nomic-embed-text
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠼ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠧ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest
# pulling 970aa74c0a90... 100% ▕▏ 274 MB
# pulling c71d239df917... 100% ▕▏  11 KB
# pulling ce4a164fc046... 100% ▕▏   17 B
# pulling 31df23ea7daa... 100% ▕▏  420 B
# verifying sha256 digest
# writing manifest
# success

# %%
# !lsof -i :11434
# Out:
# COMMAND   PID USER   FD   TYPE DEVICE SIZE/OFF NODE NAME
# ollama  16970 root    3u  IPv4 415155      0t0  TCP localhost:11434 (LISTEN)

# %%
# !kill -9 3397
# Out:
# /bin/bash: line 1: kill: (3397) - No such process

# %%
# !lsof -i :11434

# %%
# !nohup ollama serve > ollama.log 2>&1 &

# %%
TEMP_FOLDER = './_temp'
CHROMA_PATH = 'chroma'
COLLECTION_NAME = 'local-rag'
LLM_MODEL = 'mistral'
TEXT_EMBEDDING_MODEL = 'nomic-embed-text'

# %%
from pyngrok import ngrok, conf

conf.get_default().auth_token = "2mLFit1NLrroBlEQylbg4wae8Wd_4F9XUsDDVsCWG8oWpgbvL" # Replace with your actual authtoken

# Now connect
public_url = ngrok.connect(8123)
print(f"Public URL: {public_url}")
# Out:
# Public URL: NgrokTunnel: "https://445d-35-240-132-238.ngrok-free.app" -> "http://localhost:8123"

# %%
# !python3 app.py
# Out:
#  * Serving Flask app 'app'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:8123
#  * Running on http://172.28.0.12:8123
# Press CTRL+C to quit
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 420-251-751

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/app.py /content/drive/MyDrive/
# !cp /content/embed_module.py /content/drive/MyDrive/
# !cp /content/query.py /content/drive/MyDrive/
